# %%
import boto3
import panda as pd

s3 = boto3.client("s3")
bucket = "csv-file-store-ec51f700"

obj = s3.get_object(Bucket=bucket, Key="s3://csv-file-store-ec51f700/dzd-3lz7fcr1rwmmkw/5h6d6xccl72dn4/dev/data/2025-08-15_composition_sp500.csv")
df = pd.read_csv(obj['Body'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import boto3
# ----> 2 import panda as pd
#       4 s3 = boto3.client("s3")
#       5 bucket = "csv-file-store-ec51f700"
#
# ModuleNotFoundError: No module named 'panda'
